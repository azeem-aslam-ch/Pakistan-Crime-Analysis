# %%
#include lib
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
data=pd.read_csv('/kaggle/input/pakistan-crimes-by-type/248a92b9-5817-43f2-b0e7-6d45a45a8ee9.csv')
data
# Out:
#     _id  Year                Offence  Punjab  Sindh      KP  Balochistan  \
# 0     1  2012                 Murder    6128   3726    2958          711
# 1     2  2012      Attempt to Murder    7641   3732    2892          583
# 2     3  2012  Kidnapping /Abduction   15699   3077    1052          386
# 3     4  2012                Dacoity    2715   1341      60           98
# 4     5  2012                Robbery   12181   4320     134          160
# 5     6  2012               Burglary   14740   1680     500          117
# 6     7  2012           Cattle Theft    8115    630     118           77
# 7     8  2012            Other Theft   34719   2976     717          332
# 8     9  2012                 Others  292665  57206  139344         5745
# 9    10  2012   TOTAL RECORDED CRIME  394603  78688  147775         8209
# 10   11  2013                 Murder    5969   3854    3163          639
# 11   12  2013      Attempt to Murder    6935   3568    3146          482
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   _id          60 non-null     int64
#  1   Year         60 non-null     int64
#  2   Offence      60 non-null     object
#  3   Punjab       60 non-null     int64
#  4   Sindh        60 non-null     int64
#  5   KP           60 non-null     int64
#  6   Balochistan  60 non-null     int64
#  7   Islamabad    60 non-null     int64
#  8   Railways     60 non-null     int64
#  9   G.B          60 non-null     int64
#  10  AJK          60 non-null     int64
#  11  Pakistan     60 non-null     int64
# dtypes: int64(11), object(1)
# memory usage: 5.8+ KB

# %%
data.columns
# Out:
# Index(['_id', 'Year', 'Offence', 'Punjab', 'Sindh', 'KP', 'Balochistan',
#        'Islamabad', 'Railways', 'G.B', 'AJK', 'Pakistan'],
#       dtype='object')

# %%
df=pd.melt(data,id_vars=['_id','Year','Offence'],
         var_name="Palce",
         value_name="Value" )
df
# Out:
#      _id  Year                Offence     Palce   Value
# 0      1  2012                 Murder    Punjab    6128
# 1      2  2012      Attempt to Murder    Punjab    7641
# 2      3  2012  Kidnapping /Abduction    Punjab   15699
# 3      4  2012                Dacoity    Punjab    2715
# 4      5  2012                Robbery    Punjab   12181
# ..   ...   ...                    ...       ...     ...
# 535   56  2017               Burglary  Pakistan   13833
# 536   57  2017           Cattle Theft  Pakistan    5342
# 537   58  2017            Other Theft  Pakistan   37304
# 538   59  2017                 Others  Pakistan  577611
# 539   60  2017   TOTAL RECORDED CRIME  Pakistan  683925
#
# [540 rows x 5 columns]

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1623816333283' style='position: relative'>
# <noscript>
# <a href='#'><img alt='Total  Crimes In Pakistan ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Sh&#47;Sheet1_16238144636600&#47;Sheet1&#47;1_rss.png' style='border: none' /></a>
# </noscript>
# <object class='tableauViz'  style='display:none;'>
# <param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' />
# <param name='embed_code_version' value='3' />
# <param name='site_root' value='' />
# <param name='name' value='Sheet1_16238144636600&#47;Sheet1' />
# <param name='tabs' value='no' />
# <param name='toolbar' value='yes' />
# <param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Sh&#47;Sheet1_16238144636600&#47;Sheet1&#47;1.png' />
# <param name='animate_transition' value='yes' />
# <param name='display_static_image' value='yes' />
# <param name='display_spinner' value='yes' />
# <param name='display_overlay' value='yes' />
# <param name='display_count' value='yes' />
# <param name='language' value='en-US' />
# </object>
# </div>
# <script type='text/javascript'> var divElement = document.getElementById('viz1623816333283'); var vizElement = divElement.getElementsByTagName('object')[0]; vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px'; var scriptElement = document.createElement('script'); scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js'; vizElement.parentNode.insertBefore(scriptElement, vizElement);
# </script>
# Out:
# <div class='tableauPlaceholder' id='viz1623816333283' style='position: relative'>
# <noscript>
# <a href='#'><img alt='Total  Crimes In Pakistan ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Sh&#47;Sheet1_16238144636600&#47;Sheet1&#47;1_rss.png' style='border: none' /></a>
# </noscript>
# <object class='tableauViz'  style='display:none;'>
# <param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' />
# <param name='embed_code_version' value='3' />
# <param name='site_root' value='' />
# <param name='name' value='Sheet1_16238144636600&#47;Sheet1' />
# <param name='tabs' value='no' />
# <param name='toolbar' value='yes' />
# <param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Sh&#47;Sheet1_16238144636600&#47;Sheet1&#47;1.png' />
# <param name='animate_transition' value='yes' />
# <param name='display_static_image' value='yes' />
# <param name='display_spinner' value='yes' />
# ...

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1623817604018' style='position: relative'>
# <noscript><a href='#'>
# <img alt='Numbers Of Murders In Year(2012-2017) ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Sh&#47;Sheet3_16237450536850&#47;Sheet3&#47;1_rss.png' style='border: none' /></a>
# </noscript>
# <object class='tableauViz'  style='display:none;'>
# <param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' />
# <param name='embed_code_version' value='3' />
# <param name='site_root' value='' />
# <param name='name' value='Sheet3_16237450536850&#47;Sheet3' />
# <param name='tabs' value='no' />
# <param name='toolbar' value='yes' />
# <param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Sh&#47;Sheet3_16237450536850&#47;Sheet3&#47;1.png' /> <param name='animate_transition' value='yes' />
# <param name='display_static_image' value='yes' />
# <param name='display_spinner' value='yes' />
# <param name='display_overlay' value='yes' />
# <param name='display_count' value='yes' />
# <param name='language' value='en-US' />
# </object>
# </div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1623817604018');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);
# </script>
# Out:
# <div class='tableauPlaceholder' id='viz1623817604018' style='position: relative'>
# <noscript><a href='#'>
# <img alt='Numbers Of Murders In Year(2012-2017) ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Sh&#47;Sheet3_16237450536850&#47;Sheet3&#47;1_rss.png' style='border: none' /></a>
# </noscript>
# <object class='tableauViz'  style='display:none;'>
# <param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' />
# <param name='embed_code_version' value='3' />
# <param name='site_root' value='' />
# <param name='name' value='Sheet3_16237450536850&#47;Sheet3' />
# <param name='tabs' value='no' />
# <param name='toolbar' value='yes' />
# <param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Sh&#47;Sheet3_16237450536850&#47;Sheet3&#47;1.png' /> <param name='animate_transition' value='yes' />
# <param name='display_static_image' value='yes' />
# <param name='display_spinner' value='yes' />
# ...

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1623817241967' style='position: relative'>
# <noscript>
# <a href='#'><img alt='Total Crimes In Pakistan Show through Map  ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Sh&#47;Sheet10_16237453203360&#47;Sheet10&#47;1_rss.png' style='border: none' /></a>
# </noscript>
# <object class='tableauViz'  style='display:none;'>
# <param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' />
# <param name='embed_code_version' value='3' />
# <param name='site_root' value='' />
# <param name='name' value='Sheet10_16237453203360&#47;Sheet10' />
# <param name='tabs' value='no' />
# <param name='toolbar' value='yes' />
# <param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Sh&#47;Sheet10_16237453203360&#47;Sheet10&#47;1.png' />
# <param name='animate_transition' value='yes' />
# <param name='display_static_image' value='yes' />
# <param name='display_spinner' value='yes' />
# <param name='display_overlay' value='yes' />
# <param name='display_count' value='yes' />
# <param name='language' value='en-US' />
# </object>
# </div>
# <script type='text/javascript'>
# var divElement = document.getElementById('viz1623817241967');
# var vizElement = divElement.getElementsByTagName('object')[0];
# vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px'; var scriptElement = document.createElement('script');scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';vizElement.parentNode.insertBefore(scriptElement, vizElement);
# </script>
# Out:
# <div class='tableauPlaceholder' id='viz1623817241967' style='position: relative'>
# <noscript>
# <a href='#'><img alt='Total Crimes In Pakistan Show through Map  ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Sh&#47;Sheet10_16237453203360&#47;Sheet10&#47;1_rss.png' style='border: none' /></a>
# </noscript>
# <object class='tableauViz'  style='display:none;'>
# <param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' />
# <param name='embed_code_version' value='3' />
# <param name='site_root' value='' />
# <param name='name' value='Sheet10_16237453203360&#47;Sheet10' />
# <param name='tabs' value='no' />
# <param name='toolbar' value='yes' />
# <param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Sh&#47;Sheet10_16237453203360&#47;Sheet10&#47;1.png' />
# <param name='animate_transition' value='yes' />
# <param name='display_static_image' value='yes' />
# <param name='display_spinner' value='yes' />
# ...
